# %% [markdown]
# <a href="https://colab.research.google.com/github/majeedaferoz/majeeda-task1/blob/main/TASK_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from matplotlib import pyplot as plt

# %%
# Load the iris dataset
iris = datasets.load_iris()

# %%
# Convert the dataset to a Pandas DataFrame
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df['species'] = iris.target

# %%
plt.scatter(df['sepal length (cm)'], df['sepal width (cm)'], c=df['species'], cmap='Set1')
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.show()

# %%
# Use the KMeans algorithm to cluster the data
kmeans = KMeans(n_clusters=3)
kmeans.fit(df)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
# Predict the cluster labels for each data point
labels = kmeans.predict(df)

# %%
# Visualize the clusters
pca = PCA(n_components=2)
pca_df = pca.fit_transform(df)
plt.scatter(pca_df[:, 0], pca_df[:, 1], c=labels, cmap='Set1')
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.show()
